# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
import matplotlib.pyplot as pyplot
from matplotlib import style
import pickle

# %% [markdown]
# ### Read and clear given data

# %%
students = pd.read_csv('student-mat.csv', sep=';')
students = students[['G1', 'G2', 'G3', 'studytime', 'failures', 'absences']]
students.head()
# Out:
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4

# %% [markdown]
# ### Create train and test datasets

# %%
predict = "G3"
x = np.array(students.drop([predict], axis=1))
y = np.array(students[predict])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ### Saving the best trained model

# %%
# best = 0
# for _ in range(1000):
#     x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.2)


#     model = linear_model.LinearRegression()
#     model.fit(x_train, y_train)
#     acc = model.score(x_test, y_test)

#     if acc > best:
#         best = acc
#         with open("students_model.pickle", "wb") as f:
#             pickle.dump(model, f)
# model.score(x_test, y_test)
# Out:
# 0.9321893261709141

# %%
pickle_file = open("students_model.pickle", "rb")
linear = pickle.load(pickle_file)
linear.score(x_test, y_test)
# Out:
# 0.9341050409350924

# %% [markdown]
# ### Looking at the corelation from different parameters

# %%
style.use('ggplot')
for i in students.columns:
    pyplot.scatter(students[i], students['G3'])
    pyplot.xlabel(i)
    pyplot.ylabel('G3')
    pyplot.show()
# Out:
# 0.9052990063861
